# %%
import pandas as pd

# %% [markdown]
# ## Load the Data:

# %%
df = pd.read_csv('data/uber_data.csv')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1         1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2         2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3         2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4         2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           2.50        -73.976746        40.765152           1
# 1           2.90        -73.983482        40.767925           1
# 2          19.98        -73.782021        40.644810           1
# 3          10.78        -73.863419        40.769814           1
# 4          30.43        -73.971741        40.792183           3
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %% [markdown]
# ## Clean the Data

# %% [markdown]
# #### null values

# %%
df.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RatecodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
df.shape
# Out:
# (100000, 19)

# %% [markdown]
# #### the type of each columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               100000 non-null  int64
#  1   tpep_pickup_datetime   100000 non-null  object
#  2   tpep_dropoff_datetime  100000 non-null  object
#  3   passenger_count        100000 non-null  int64
#  4   trip_distance          100000 non-null  float64
#  5   pickup_longitude       100000 non-null  float64
#  6   pickup_latitude        100000 non-null  float64
#  7   RatecodeID             100000 non-null  int64
#  8   store_and_fwd_flag     100000 non-null  object
#  9   dropoff_longitude      100000 non-null  float64
#  10  dropoff_latitude       100000 non-null  float64
#  11  payment_type           100000 non-null  int64
#  12  fare_amount            100000 non-null  float64
#  13  extra                  100000 non-null  float64
# ...

# %%
df.describe(include="all")
# Out:
#             VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# count   100000.00000               100000                100000
# unique           NaN                38332                 39981
# top              NaN  2016-03-10 09:35:06   2016-03-11 00:00:00
# freq             NaN                   14                    18
# mean         1.88327                  NaN                   NaN
# std          0.32110                  NaN                   NaN
# min          1.00000                  NaN                   NaN
# 25%          2.00000                  NaN                   NaN
# 50%          2.00000                  NaN                   NaN
# 75%          2.00000                  NaN                   NaN
# max          2.00000                  NaN                   NaN
#
#         passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# count     100000.000000  100000.000000     100000.000000    100000.000000
# ...

# %% [markdown]
# #### check duplicated

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RatecodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %% [markdown]
# #### the trip that has 0 passengers

# %%
count_zero = (df["passenger_count"] == 0).sum()
print(count_zero)
# Out:
# 3

# %% [markdown]
# #### remove this 3 trips that has 0 passengers

# %%
df = df[df["passenger_count"] > 0]

# %%
print((df["passenger_count"] == 0).sum())
# Out:
# 0

# %% [markdown]
# #### the trip distance that has 0

# %%
count_zero_distance = (df["trip_distance"] == 0).sum()

# %%
print(count_zero_distance)
# Out:
# 582

# %% [markdown]
# #### The "Divide by Zero" Crash: Later in your dashboard, i will likely want to calculate "Average Cost per Mile" or "Average Speed"

# %%
df = df[df["trip_distance"] > 0]

# %%
print((df['trip_distance'] == 0 ).sum())
# Out:
# 0

# %% [markdown]
# #### amount negative or zero

# %%
count_negative_amount = (df["total_amount"] <= 0).sum()

# %%
print(count_negative_amount)
# Out:
# 52

# %%
# Filter to keep only trips with positive total amounts
df = df[df['total_amount'] > 0]

print((df['total_amount'] <= 0).sum())
# Out:
# 0

# %% [markdown]
# #### converting the date to date time pd

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99363 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               99363 non-null  int64
#  1   tpep_pickup_datetime   99363 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  99363 non-null  datetime64[ns]
#  3   passenger_count        99363 non-null  int64
#  4   trip_distance          99363 non-null  float64
#  5   pickup_longitude       99363 non-null  float64
#  6   pickup_latitude        99363 non-null  float64
#  7   RatecodeID             99363 non-null  int64
#  8   store_and_fwd_flag     99363 non-null  object
#  9   dropoff_longitude      99363 non-null  float64
#  10  dropoff_latitude       99363 non-null  float64
#  11  payment_type           99363 non-null  int64
#  12  fare_amount            99363 non-null  float64
#  13  extra                  99363 non-null  float64
# ...

# %% [markdown]
# #### reset the index to give it to trip id because i have removed rows

# %%
df = df.reset_index(drop=True)

# %%
df['trip_id']= df.index

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1           2016-03-01   2016-03-01 00:07:55                1
# 1         1           2016-03-01   2016-03-01 00:11:06                1
# 2         2           2016-03-01   2016-03-01 00:31:06                2
# 3         2           2016-03-01   2016-03-01 00:00:00                3
# 4         2           2016-03-01   2016-03-01 00:00:00                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           2.50        -73.976746        40.765152           1
# 1           2.90        -73.983482        40.767925           1
# 2          19.98        -73.782021        40.644810           1
# 3          10.78        -73.863419        40.769814           1
# 4          30.43        -73.971741        40.792183           3
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
col = "trip_id"
df = df[[col] + [c for c in df.columns if c != col]]

# %%
df.head()
# Out:
#    trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        0         1           2016-03-01   2016-03-01 00:07:55
# 1        1         1           2016-03-01   2016-03-01 00:11:06
# 2        2         2           2016-03-01   2016-03-01 00:31:06
# 3        3         2           2016-03-01   2016-03-01 00:00:00
# 4        4         2           2016-03-01   2016-03-01 00:00:00
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           2.50        -73.976746        40.765152
# 1                1           2.90        -73.983482        40.767925
# 2                2          19.98        -73.782021        40.644810
# 3                3          10.78        -73.863419        40.769814
# 4                5          30.43        -73.971741        40.792183
#
#    RatecodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0           1                  N         -74.004265         40.746128
# ...

# %% [markdown]
# ## build the datetime_dim table

# %%
# 1. Select the columns
datetime_dim = df[['tpep_pickup_datetime', 'tpep_dropoff_datetime']]

# 2. Drop Duplicates FIRST to get unique combinations
datetime_dim = datetime_dim.drop_duplicates(subset=['tpep_pickup_datetime', 'tpep_dropoff_datetime'])

# 3. Reset Index AFTER to create a clean sequential ID (0, 1, 2, ...)
datetime_dim = datetime_dim.reset_index(drop=True)

# 4. Assign the index to be the Primary Key
datetime_dim['datetime_id'] = datetime_dim.index

# 5. Extract Pickup Features
datetime_dim['pick_hour'] = datetime_dim['tpep_pickup_datetime'].dt.hour
datetime_dim['pick_day'] = datetime_dim['tpep_pickup_datetime'].dt.day
datetime_dim['pick_month'] = datetime_dim['tpep_pickup_datetime'].dt.month
datetime_dim['pick_year'] = datetime_dim['tpep_pickup_datetime'].dt.year
datetime_dim['pick_weekday'] = datetime_dim['tpep_pickup_datetime'].dt.weekday

# 6. Extract Dropoff Features
datetime_dim['drop_hour'] = datetime_dim['tpep_dropoff_datetime'].dt.hour
datetime_dim['drop_day'] = datetime_dim['tpep_dropoff_datetime'].dt.day
datetime_dim['drop_month'] = datetime_dim['tpep_dropoff_datetime'].dt.month
datetime_dim['drop_year'] = datetime_dim['tpep_dropoff_datetime'].dt.year
datetime_dim['drop_weekday'] = datetime_dim['tpep_dropoff_datetime'].dt.weekday

# 7. Reorder columns
datetime_dim = datetime_dim[['datetime_id', 'tpep_pickup_datetime', 'pick_hour', 'pick_day', 'pick_month', 'pick_year', 'pick_weekday',
                             'tpep_dropoff_datetime', 'drop_hour', 'drop_day', 'drop_month', 'drop_year', 'drop_weekday']]

# Verify
datetime_dim.head()
# Out:
#    datetime_id tpep_pickup_datetime  pick_hour  pick_day  pick_month  \
# 0            0  2016-03-01 00:00:00          0         1           3
# 1            1  2016-03-01 00:00:00          0         1           3
# 2            2  2016-03-01 00:00:00          0         1           3
# 3            3  2016-03-01 00:00:00          0         1           3
# 4            4  2016-03-01 00:00:01          0         1           3
#
#    pick_year  pick_weekday tpep_dropoff_datetime  drop_hour  drop_day  \
# 0       2016             1   2016-03-01 00:07:55          0         1
# 1       2016             1   2016-03-01 00:11:06          0         1
# 2       2016             1   2016-03-01 00:31:06          0         1
# 3       2016             1   2016-03-01 00:00:00          0         1
# 4       2016             1   2016-03-01 00:16:04          0         1
#
#    drop_month  drop_year  drop_weekday
# 0           3       2016             1
# 1           3       2016             1
# ...

# %% [markdown]
# ## build the dim_rate_code and payments table

# %%
# --- 1. Define the Mapping Dictionaries ---
rate_code_type = {
    1: "Standard rate",
    2: "JFK",
    3: "Newark",
    4: "Nassau or Westchester",
    5: "Negotiated fare",
    6: "Group ride"
}

payment_type_name = {
    1: "Credit card",
    2: "Cash",
    3: "No charge",
    4: "Dispute",
    5: "Unknown",
    6: "Voided trip"
}

# --- 2. Build dim_rate_code ---
# Select and drop duplicates
rate_code_dim = df[['RatecodeID']].drop_duplicates().reset_index(drop=True)

# Create the Primary Key
rate_code_dim['rate_code_id'] = rate_code_dim.index

# Map the ID to the Name using the dictionary
rate_code_dim['rate_code_name'] = rate_code_dim['RatecodeID'].map(rate_code_type)

# Reorder columns
rate_code_dim = rate_code_dim[['rate_code_id', 'RatecodeID', 'rate_code_name']]

# --- 3. Build dim_payment_type ---
# Select and drop duplicates
payment_type_dim = df[['payment_type']].drop_duplicates().reset_index(drop=True)

# Create the Primary Key
payment_type_dim['payment_type_id'] = payment_type_dim.index

# Map the ID to the Name
payment_type_dim['payment_type_name'] = payment_type_dim['payment_type'].map(payment_type_name)

# Reorder columns
payment_type_dim = payment_type_dim[['payment_type_id', 'payment_type', 'payment_type_name']]

# --- 4. Verify ---
print("Rate Code Dimension:")
print(rate_code_dim.head())
print("\nPayment Type Dimension:")
print(payment_type_dim.head())
# Out:
# Rate Code Dimension:
#    rate_code_id  RatecodeID         rate_code_name
# 0             0           1          Standard rate
# 1             1           3                 Newark
# 2             2           2                    JFK
# 3             3           5        Negotiated fare
# 4             4           4  Nassau or Westchester
#
# Payment Type Dimension:
#    payment_type_id  payment_type payment_type_name
# 0                0             1       Credit card
# 1                1             2              Cash
# 2                2             3         No charge
# 3                3             4           Dispute
